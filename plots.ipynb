# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma),color='k')
plt.axis('off')
plt.savefig('marg1.png',transparent=True)
plt.show()

# %%
mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu-1, sigma/2)+stats.norm.pdf(x, mu+1, sigma/2),color='k')
plt.axis('off')
plt.savefig('marg2.png',transparent=True)
plt.show()

# %%
mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu-1, sigma/4)+stats.norm.pdf(x, mu+1, sigma/4),color='k')
plt.axis('off')
plt.savefig('marg3.png',transparent=True)
plt.show()
